# %%
# coding: utf-8

# %%
# %reload_ext mocodo_magic

# %%
# %%mocodo --title=cod --mld --colors ocean --shapes copperplate --relations diagram markdown_data_dict mysql
#
# RATIO : date[TIMESTAMP], value[FLOAT]
# HEADSHOTS : date[TIMESTAMP], value[FLOAT]
#
# GAMETIME : date[TIMESTAMP], value[INTEGER]
# MATCHES : date[TIMESTAMP], value[INTEGER]
#
# DEATHS : date[TIMESTAMP], value[INTEGER]
# KILLS : date[TIMESTAMP], value[INTEGER]
#
# WALLBANGS : date[TIMESTAMP], value[INTEGER]
# Out:
# <html>
# <head>
# <meta charset='utf-8'>
# <style>
#   #mld .relation { font-variant: small-caps; font-weight: bold }
#   #mld .primary { text-decoration: underline }
#   #mld .foreign { font-style: oblique }
#   #mld .normal { }
# </style>
# </head>
# <body>
# <div id='mld'>
# <div>
#   <span class='relation'>RATIO</span> (
#     <span class='primary'>date</span>,
#     <span class='normal'>value</span>
#   )
# </div>
# <div>
#   <span class='relation'>HEADSHOTS</span> (
#     <span class='primary'>date</span>,
#     <span class='normal'>value</span>
#   )
# </div>
# <div>
#   <span class='relation'>GAMETIME</span> (
#     <span class='primary'>date</span>,
#     <span class='normal'>value</span>
#   )
# </div>
# <div>
#   <span class='relation'>MATCHES</span> (
#     <span class='primary'>date</span>,
#     <span class='normal'>value</span>
#   )
# </div>
# <div>
#   <span class='relation'>DEATHS</span> (
#     <span class='primary'>date</span>,
# ...

# %%
# %load mocodo_notebook/sandbox_mysql.sql
CREATE DATABASE IF NOT EXISTS `COD` DEFAULT CHARACTER SET utf8 COLLATE utf8_general_ci;
USE `COD`;

CREATE TABLE `RATIO` (
  `date` TIMESTAMP,
  `value` FLOAT,
  PRIMARY KEY (`date`)
) ENGINE=InnoDB DEFAULT CHARSET=utf8;

CREATE TABLE `HEADSHOTS` (
  `date` TIMESTAMP,
  `value` FLOAT,
  PRIMARY KEY (`date`)
) ENGINE=InnoDB DEFAULT CHARSET=utf8;

CREATE TABLE `GAMETIME` (
  `date` TIMESTAMP,
  `value` INTEGER,
  PRIMARY KEY (`date`)
) ENGINE=InnoDB DEFAULT CHARSET=utf8;

CREATE TABLE `MATCHES` (
  `date` TIMESTAMP,
  `value` INTEGER,
  PRIMARY KEY (`date`)
) ENGINE=InnoDB DEFAULT CHARSET=utf8;

CREATE TABLE `DEATHS` (
  `date` TIMESTAMP,
  `value` INTEGER,
  PRIMARY KEY (`date`)
) ENGINE=InnoDB DEFAULT CHARSET=utf8;

CREATE TABLE `KILLS` (
  `date` TIMESTAMP,
  `value` INTEGER,
  PRIMARY KEY (`date`)
) ENGINE=InnoDB DEFAULT CHARSET=utf8;

CREATE TABLE `WALLBANGS` (
  `date` TIMESTAMP,
  `value` INTEGER,
  PRIMARY KEY (`date`)
) ENGINE=InnoDB DEFAULT CHARSET=utf8;
